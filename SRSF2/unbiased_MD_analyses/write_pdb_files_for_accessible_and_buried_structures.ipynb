# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import MDAnalysis.analysis.distances
import MDAnalysis as md
import mdtraj as mdj
import MDAnalysis.analysis.contacts
import pandas as pd
import MDAnalysis.analysis.rms
import os
from MDAnalysis.analysis.dihedrals import Dihedral
from MDAnalysis.analysis.rms import RMSF
from MDAnalysis.analysis import rms, align
import matplotlib
matplotlib.rcParams['pdf.fonttype'] = 42

path = '/Volumes/Elements/PTM_project/SRSF2/unbiased_1us/'

# %%
sim=1

u = md.Universe(path+'sim{}/processed.pdb'.format(sim),path+'sim{}/fit.xtc'.format(sim))
protein = u.select_atoms('all')

resids=[14,22,25]
restypes=['THR','THR','THR']

for resid,resname in zip(resids,restypes):
    
    print('Analysing residue {}{}...'.format(resname,resid))
    
    sasa=np.loadtxt(path+"sim{}/sasa{}{}.xvg".format(sim,resname,resid+57),skiprows=25)
    
    # extract second half of trajectory (ensuring structure/system is well equilibrated at that point)
    sasa_secondhalf=sasa[int(sasa.shape[0]/2):]
    # find minimum and maximum
    sasa_min = np.min(sasa_secondhalf[:,2])
    sasa_max = np.max(sasa_secondhalf[:,2])

    # find first frames where min/max values are
    idx_min = np.where(sasa_secondhalf[:,2]==sasa_min)[0][0]+int(sasa.shape[0]/2) # the +int(sasa.shape[0]/2) shifts the index to the second half
    idx_max = np.where(sasa_secondhalf[:,2]==sasa_max)[0][0]+int(sasa.shape[0]/2)

    time_min = sasa[:,0][idx_min]
    time_max = sasa[:,0][idx_max]

    print('Minimum SASA: {:.2f} nm^2 at {:.1f} ps'.format(sasa_min,time_min))
    print('Maximum SASA: {:.2f} nm^2 at {:.1f} ps'.format(sasa_max,time_max))

    # write pdb structures
    u.trajectory[idx_min]
    with md.Writer(path+'sim{}/minSASA_RESID{}_{:.2f}nm2_at_{:.1f}ps.pdb'.format(sim,resid,sasa_min,time_min),protein.n_atoms) as W:
        W.write(protein)

    u.trajectory[idx_max]
    with md.Writer(path+'sim{}/maxSASA_RESID{}_{:.2f}nm2_at_{:.1f}ps.pdb'.format(sim,resid,sasa_max,time_max),protein.n_atoms) as W:
        W.write(protein)

    print('Structures written to PDB files!')
# Out:
# Analysing residue THR14...
# Minimum SASA: 0.00 nm^2 at 512220.0 ps
# Maximum SASA: 0.70 nm^2 at 871000.0 ps
# Structures written to PDB files!
# Analysing residue THR22...
# Minimum SASA: 0.00 nm^2 at 502060.0 ps
# Maximum SASA: 0.97 nm^2 at 585400.0 ps
# Structures written to PDB files!
# Analysing residue THR25...
# Minimum SASA: 0.00 nm^2 at 500800.0 ps
# Maximum SASA: 1.02 nm^2 at 819180.0 ps
# Structures written to PDB files!

# %%
sim=2

u = md.Universe(path+'sim{}/processed.pdb'.format(sim),path+'sim{}/fit.xtc'.format(sim))
protein = u.select_atoms('all')

resids=[14,22,25]
restypes=['THR','THR','THR']

for resid,resname in zip(resids,restypes):
    
    print('Analysing residue {}{}...'.format(resname,resid))
    
    sasa=np.loadtxt(path+"sim{}/sasa{}{}.xvg".format(sim,resname,resid+57),skiprows=25)
    
    # extract second half of trajectory (ensuring structure/system is well equilibrated at that point)
    sasa_secondhalf=sasa[int(sasa.shape[0]/2):]
    # find minimum and maximum
    sasa_min = np.min(sasa_secondhalf[:,2])
    sasa_max = np.max(sasa_secondhalf[:,2])

    # find first frames where min/max values are
    idx_min = np.where(sasa_secondhalf[:,2]==sasa_min)[0][0]+int(sasa.shape[0]/2) # the +int(sasa.shape[0]/2) shifts the index to the second half
    idx_max = np.where(sasa_secondhalf[:,2]==sasa_max)[0][0]+int(sasa.shape[0]/2)

    time_min = sasa[:,0][idx_min]
    time_max = sasa[:,0][idx_max]

    print('Minimum SASA: {:.2f} nm^2 at {:.1f} ps'.format(sasa_min,time_min))
    print('Maximum SASA: {:.2f} nm^2 at {:.1f} ps'.format(sasa_max,time_max))

    # write pdb structures
    u.trajectory[idx_min]
    with md.Writer(path+'sim{}/minSASA_RESID{}_{:.2f}nm2_at_{:.1f}ps.pdb'.format(sim,resid,sasa_min,time_min),protein.n_atoms) as W:
        W.write(protein)

    u.trajectory[idx_max]
    with md.Writer(path+'sim{}/maxSASA_RESID{}_{:.2f}nm2_at_{:.1f}ps.pdb'.format(sim,resid,sasa_max,time_max),protein.n_atoms) as W:
        W.write(protein)

    print('Structures written to PDB files!')
# Out:
# Analysing residue THR14...
# Minimum SASA: 0.00 nm^2 at 509020.0 ps
# Maximum SASA: 0.64 nm^2 at 586480.0 ps
# Structures written to PDB files!
# Analysing residue THR22...
# Minimum SASA: 0.00 nm^2 at 500040.0 ps
# Maximum SASA: 1.00 nm^2 at 971160.0 ps
# Structures written to PDB files!
# Analysing residue THR25...
# Minimum SASA: 0.00 nm^2 at 500060.0 ps
# Maximum SASA: 0.45 nm^2 at 964520.0 ps
# Structures written to PDB files!

# %%
sim=3

u = md.Universe(path+'sim{}/processed.pdb'.format(sim),path+'sim{}/fit.xtc'.format(sim))
protein = u.select_atoms('all')

resids=[14,22,25]
restypes=['THR','THR','THR']

for resid,resname in zip(resids,restypes):
    
    print('Analysing residue {}{}...'.format(resname,resid))
    
    sasa=np.loadtxt(path+"sim{}/sasa{}{}.xvg".format(sim,resname,resid+57),skiprows=25)
    
    # extract second half of trajectory (ensuring structure/system is well equilibrated at that point)
    sasa_secondhalf=sasa[int(sasa.shape[0]/2):]
    # find minimum and maximum
    sasa_min = np.min(sasa_secondhalf[:,2])
    sasa_max = np.max(sasa_secondhalf[:,2])

    # find first frames where min/max values are
    idx_min = np.where(sasa_secondhalf[:,2]==sasa_min)[0][0]+int(sasa.shape[0]/2) # the +int(sasa.shape[0]/2) shifts the index to the second half
    idx_max = np.where(sasa_secondhalf[:,2]==sasa_max)[0][0]+int(sasa.shape[0]/2)

    time_min = sasa[:,0][idx_min]
    time_max = sasa[:,0][idx_max]

    print('Minimum SASA: {:.2f} nm^2 at {:.1f} ps'.format(sasa_min,time_min))
    print('Maximum SASA: {:.2f} nm^2 at {:.1f} ps'.format(sasa_max,time_max))

    # write pdb structures
    u.trajectory[idx_min]
    with md.Writer(path+'sim{}/minSASA_RESID{}_{:.2f}nm2_at_{:.1f}ps.pdb'.format(sim,resid,sasa_min,time_min),protein.n_atoms) as W:
        W.write(protein)

    u.trajectory[idx_max]
    with md.Writer(path+'sim{}/maxSASA_RESID{}_{:.2f}nm2_at_{:.1f}ps.pdb'.format(sim,resid,sasa_max,time_max),protein.n_atoms) as W:
        W.write(protein)

    print('Structures written to PDB files!')
# Out:
# Analysing residue THR14...
# Minimum SASA: 0.00 nm^2 at 501500.0 ps
# Maximum SASA: 0.54 nm^2 at 630680.0 ps
# Structures written to PDB files!
# Analysing residue THR22...
# Minimum SASA: 0.00 nm^2 at 500040.0 ps
# Maximum SASA: 1.23 nm^2 at 740540.0 ps
# Structures written to PDB files!
# Analysing residue THR25...
# Minimum SASA: 0.00 nm^2 at 533840.0 ps
# Maximum SASA: 0.69 nm^2 at 515840.0 ps
# Structures written to PDB files!

# %%
# input structures for phosphorylated variants MD:
# pT14: sim1 maxSASA
# pT22: sim3 maxSASA
# pT25: sim1 maxSASA
