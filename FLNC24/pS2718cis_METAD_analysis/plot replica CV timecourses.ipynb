# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.ndimage
from scipy.ndimage import gaussian_filter
path = '/Volumes/Elements/PTM_project/FLNC24/pS2718cis_METAD/DATA_PLUMED/'

# %%
nreplica=3


plt.figure(figsize=(8,3))

for i in range(nreplica):
    
    plt.subplot(1,3,i+1)
    
    dat = np.loadtxt(path+'COLVAR.{}'.format(i+1))
    
    plt.title('SIM{}'.format(i+1))
    plt.scatter(dat[:,0]/1000,dat[:,1],alpha = 0.05,s=0.2,color = 'black')
    
    plt.ylim(-np.pi,np.pi)
    
    plt.xlabel('Time (ns)')
    plt.ylabel('Zeta')
    
plt.subplots_adjust(hspace = 0.2,wspace = 0.2)
plt.tight_layout()
plt.savefig('replicas_zeta.png')

# %%
nreplica=3


plt.figure(figsize=(8,3))

for i in range(nreplica):
    
    plt.subplot(1,3,i+1)
    
    dat = np.loadtxt(path+'COLVAR.{}'.format(i+1))
    
    plt.title('SIM{}'.format(i+1))
    plt.scatter(dat[:,0]/1000,dat[:,2],alpha = 0.05,s=0.2,color = 'black')
    
    plt.ylim(-np.pi,np.pi)
    
    plt.xlabel('Time (ns)')
    plt.ylabel('Psi')
    
plt.subplots_adjust(hspace = 0.2,wspace = 0.2)
plt.tight_layout()
plt.savefig('replicas_psi.png')

# %%
nreplica=3


plt.figure(figsize=(8,3))

for i in range(nreplica):
    
    plt.subplot(1,3,i+1)
    
    dat = np.loadtxt(path+'../RMSD_SASA_data/rmsd_BB{}.xvg'.format(i+1),skiprows=18)
    
    plt.title('SIM{}'.format(i+1))
    plt.scatter(dat[:,0]/1000,dat[:,1],alpha = 0.05,s=0.2,color = 'black')
    
    plt.ylim(0,0.8)
    
    plt.xlabel('Time (ns)')
    plt.ylabel('BB RMSD (nm)')
    
plt.subplots_adjust(hspace = 0.2,wspace = 0.2)
plt.tight_layout()
plt.savefig('replicas_rmsd.png')

# %%
nreplica=3


plt.figure(figsize=(8,3))

for i in range(nreplica):
    
    plt.subplot(1,3,i+1)
    
    dat = np.loadtxt(path+'../RMSD_SASA_data/sasaSER2718_{}.xvg'.format(i+1),skiprows=25)
    
    plt.title('SIM{}'.format(i+1))
    plt.scatter(dat[:,0]/1000,dat[:,2],alpha = 0.05,s=0.2,color = 'black')
    
    plt.ylim(0,2.0)
    
    plt.xlabel('Time (ns)')
    plt.ylabel('pSER2718 SASA (nm$^{2}$)')
    
plt.subplots_adjust(hspace = 0.2,wspace = 0.2)
plt.tight_layout()
plt.savefig('replicas_pSER2718_SASA.png')
