# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import MDAnalysis.analysis.distances
import MDAnalysis as md
import mdtraj as mdj
import MDAnalysis.analysis.contacts
import pandas as pd
import MDAnalysis.analysis.rms
import os
from MDAnalysis.analysis.dihedrals import Dihedral
from MDAnalysis.analysis.rms import RMSF
from MDAnalysis.analysis import rms, align
import matplotlib
matplotlib.rcParams['pdf.fonttype'] = 42

path = '/Volumes/Elements/PTM_project/PARK7/unbiased_1us/'

# %%
residues = [67,139,141]
colors = ['blue','red','orange']
nsims=3
ymax = 2.0

plt.figure(figsize = (6,6))

for i in range(len(residues)):
    
    plt.subplot(2,2,i+1)
    
    vals = []
    
    for s in range(1,nsims+1):
    
        dat = np.loadtxt(path+"sim{}/sasa_chainA_TYR{}.xvg".format(s,residues[i]),skiprows=25)
    
        sasa = dat[:,2]
        time = dat[:,0]/1000 # convert to nanoseconds
        
        vals.append(np.mean(sasa[int(sasa.shape[0]/2):])) # mean of second half of traj

        plt.plot(time,sasa,color = colors[s-1],alpha=0.4,linewidth = 0.4,label = 'Sim. {}'.format(s))
    
    
    
    if i==5:
        plt.xlabel('Time (ns)')
        plt.legend()
    elif i in [0,2,4]:
        plt.ylabel('SC SASA nm$^{2}$')
        if i==4:
            plt.xlabel('Time (ns)')
        
    plt.title('TYR{}: {:.1f} ± {:.1f}'.format(residues[i],np.mean(vals),np.std(vals)/np.sqrt(nsims))+'nm$^{2}$')
    plt.ylim(0,ymax)
    plt.xlim(0,np.max(time))

    
plt.tight_layout()
plt.savefig('TYR_sidechain_SASA_analysis_chainA.pdf')

# %%
residues = [67,139,141]
colors = ['blue','red','orange']
nsims=3
ymax = 2.0

plt.figure(figsize = (6,6))

for i in range(len(residues)):
    
    plt.subplot(2,2,i+1)
    
    vals = []
    
    for s in range(1,nsims+1):
    
        dat = np.loadtxt(path+"sim{}/sasa_chainA_TYR{}.xvg".format(s,residues[i]),skiprows=25)
    
        sasa = dat[:,2]
        time = dat[:,0]/1000 # convert to nanoseconds
        
        vals.append(np.mean(sasa[int(sasa.shape[0]/2):])) # mean of second half of traj

        plt.plot(time,sasa,color = colors[s-1],alpha=0.4,linewidth = 0.4,label = 'Sim. {}'.format(s))
    
    
    
    if i==5:
        plt.xlabel('Time (ns)')
        plt.legend()
    elif i in [0,2,4]:
        plt.ylabel('SC SASA nm$^{2}$')
        if i==4:
            plt.xlabel('Time (ns)')
        
    plt.title('TYR{}: {:.1f} ± {:.1f}'.format(residues[i],np.mean(vals),np.std(vals)/np.sqrt(nsims))+'nm$^{2}$')
    plt.ylim(0,ymax)
    plt.xlim(0,np.max(time))

    
plt.tight_layout()
plt.savefig('TYR_sidechain_SASA_analysis_chainA.png')

# %%
residues = [67,139,141]
colors = ['blue','red','orange']
nsims=3
ymax = 2.0

plt.figure(figsize = (6,6))

for i in range(len(residues)):
    
    plt.subplot(2,2,i+1)
    
    vals = []
    
    for s in range(1,nsims+1):
    
        dat = np.loadtxt(path+"sim{}/sasa_chainB_TYR{}.xvg".format(s,residues[i]),skiprows=25)
    
        sasa = dat[:,2]
        time = dat[:,0]/1000 # convert to nanoseconds
        
        vals.append(np.mean(sasa[int(sasa.shape[0]/2):])) # mean of second half of traj

        plt.plot(time,sasa,color = colors[s-1],alpha=0.4,linewidth = 0.4,label = 'Sim. {}'.format(s))
    
    
    
    if i==5:
        plt.xlabel('Time (ns)')
        plt.legend()
    elif i in [0,2,4]:
        plt.ylabel('SC SASA nm$^{2}$')
        if i==4:
            plt.xlabel('Time (ns)')
        
    plt.title('TYR{}: {:.1f} ± {:.1f}'.format(residues[i],np.mean(vals),np.std(vals)/np.sqrt(nsims))+'nm$^{2}$')
    plt.ylim(0,ymax)
    plt.xlim(0,np.max(time))

    
plt.tight_layout()
plt.savefig('TYR_sidechain_SASA_analysis_chainB.pdf')

# %%
residues = [67,139,141]
colors = ['blue','red','orange']
nsims=3
ymax = 2.0

plt.figure(figsize = (6,6))

for i in range(len(residues)):
    
    plt.subplot(2,2,i+1)
    
    vals = []
    
    for s in range(1,nsims+1):
    
        dat = np.loadtxt(path+"sim{}/sasa_chainB_TYR{}.xvg".format(s,residues[i]),skiprows=25)
    
        sasa = dat[:,2]
        time = dat[:,0]/1000 # convert to nanoseconds
        
        vals.append(np.mean(sasa[int(sasa.shape[0]/2):])) # mean of second half of traj

        plt.plot(time,sasa,color = colors[s-1],alpha=0.4,linewidth = 0.4,label = 'Sim. {}'.format(s))
    
    
    
    if i==5:
        plt.xlabel('Time (ns)')
        plt.legend()
    elif i in [0,2,4]:
        plt.ylabel('SC SASA nm$^{2}$')
        if i==4:
            plt.xlabel('Time (ns)')
        
    plt.title('TYR{}: {:.1f} ± {:.1f}'.format(residues[i],np.mean(vals),np.std(vals)/np.sqrt(nsims))+'nm$^{2}$')
    plt.ylim(0,ymax)
    plt.xlim(0,np.max(time))

    
plt.tight_layout()
plt.savefig('TYR_sidechain_SASA_analysis_chainB.png')

# %%
residues = [47,57]
colors = ['blue','red','orange']
nsims=3
ymax = 1.2

plt.figure(figsize = (6,6))

for i in range(len(residues)):
    
    plt.subplot(2,2,i+1)
    
    vals = []
    
    for s in range(1,nsims+1):
    
        dat = np.loadtxt(path+"sim{}/sasa_chainA_SER{}.xvg".format(s,residues[i]),skiprows=25)
    
        sasa = dat[:,2]
        time = dat[:,0]/1000 # convert to nanoseconds
        
        vals.append(np.mean(sasa[int(sasa.shape[0]/2):])) # mean of second half of traj

        plt.plot(time,sasa,color = colors[s-1],alpha=0.4,linewidth = 0.4,label = 'Sim. {}'.format(s))
    
    
    
    if i==5:
        plt.xlabel('Time (ns)')
        plt.legend()
    elif i in [0,2,4]:
        plt.ylabel('SC SASA nm$^{2}$')
        if i==4:
            plt.xlabel('Time (ns)')
        
    plt.title('SER{}: {:.1f} ± {:.1f}'.format(residues[i],np.mean(vals),np.std(vals)/np.sqrt(nsims))+'nm$^{2}$')
    plt.ylim(0,ymax)
    plt.xlim(0,np.max(time))

    
plt.tight_layout()
plt.savefig('SER_sidechain_SASA_analysis_chainA.png')

# %%
residues = [47,57]
colors = ['blue','red','orange']
nsims=3
ymax = 1.2

plt.figure(figsize = (6,6))

for i in range(len(residues)):
    
    plt.subplot(2,2,i+1)
    
    vals = []
    
    for s in range(1,nsims+1):
    
        dat = np.loadtxt(path+"sim{}/sasa_chainB_SER{}.xvg".format(s,residues[i]),skiprows=25)
    
        sasa = dat[:,2]
        time = dat[:,0]/1000 # convert to nanoseconds
        
        vals.append(np.mean(sasa[int(sasa.shape[0]/2):])) # mean of second half of traj

        plt.plot(time,sasa,color = colors[s-1],alpha=0.4,linewidth = 0.4,label = 'Sim. {}'.format(s))
    
    
    
    if i==5:
        plt.xlabel('Time (ns)')
        plt.legend()
    elif i in [0,2,4]:
        plt.ylabel('SC SASA nm$^{2}$')
        if i==4:
            plt.xlabel('Time (ns)')
        
    plt.title('SER{}: {:.1f} ± {:.1f}'.format(residues[i],np.mean(vals),np.std(vals)/np.sqrt(nsims))+'nm$^{2}$')
    plt.ylim(0,ymax)
    plt.xlim(0,np.max(time))

    
plt.tight_layout()
plt.savefig('SER_sidechain_SASA_analysis_chainB.png')

# %%
dat.shape
# Out:
# (50001, 3)

# %%
dat2=dat

np.mean(np.array([dat[:,2],dat2[:,2]]),axis=0).shape
# Out:
# (50001,)

# %%
np.array(dat[:,2],dat2[:,2]).shape
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-ceac307f928e> in <module>
# ----> 1 np.array(dat[:,2],dat2[:,2]).shape
#
# TypeError: data type not understood
