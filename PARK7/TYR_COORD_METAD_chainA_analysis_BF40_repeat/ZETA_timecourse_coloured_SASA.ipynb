# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.ndimage
from scipy.ndimage import gaussian_filter
import matplotlib
matplotlib.rcParams['pdf.fonttype'] = 42

# functions
def hex_to_RGB(hex_str):
    """ #FFFFFF -> [255,255,255]"""
    #Pass 16 to the integer function for change of base
    return [int(hex_str[i:i+2], 16) for i in range(1,6,2)]

def get_color_gradient(c1, c2, n):
    """
    Given two hex colors, returns a color gradient
    with n colors.
    """
    assert n > 1
    c1_rgb = np.array(hex_to_RGB(c1))/255
    c2_rgb = np.array(hex_to_RGB(c2))/255
    mix_pcts = [x/(n-1) for x in range(n)]
    rgb_colors = [((1-mix)*c1_rgb + (mix*c2_rgb)) for mix in mix_pcts]
    return ["#" + "".join([format(int(round(val*255)), "02x") for val in item]) for item in rgb_colors]


def get_color_gradient3(c1, c2, c3, n):
    """
    Given three hex colors, returns a color gradient
    with n colors.
    """
    assert n > 2
    c1_rgb = np.array(hex_to_RGB(c1))/255
    c2_rgb = np.array(hex_to_RGB(c2))/255
    c3_rgb = np.array(hex_to_RGB(c3))/255
    mix_pcts = [x/(n-1) for x in range(n)]
    rgb_colors1 = [((1-mix)*c1_rgb + (mix*c2_rgb)) for mix in mix_pcts]
    rgb_colors2 = [((1-mix)*c2_rgb + (mix*c3_rgb)) for mix in mix_pcts]
    rgb_colors = rgb_colors1+rgb_colors2
    return ["#" + "".join([format(int(round(val*255)), "02x") for val in item]) for item in rgb_colors]

# read_colvar function which sorts colvar for unique entries from the back (i.e., second entry retained)
def read_colvar(colvar_file):

    data = np.loadtxt(colvar_file)
    # inverse order
    data = data[::-1]
    unique_idxs = np.array(np.unique(data[:,0], return_index=True)[1]).astype(int)[::-1] # find unique indices, first occurences
    data = data[unique_idxs]
    # original order
    data = data[::-1]

    return data

def read_xvg(xvg_file):

    data = np.loadtxt(xvg_file, skiprows=25)
    # inverse order
    data = data[::-1]
    unique_idxs = np.array(np.unique(data[:,0], return_index=True)[1]).astype(int)[::-1] # find unique indices, first occurences
    data = data[unique_idxs]
    # original order
    data = data[::-1]

    return data


from matplotlib.colors import LinearSegmentedColormap

path = '/Volumes/Elements/PTM_project/PARK7/repeat_TYR_COORD_METAD_chainA_BF40/DATA_PLUMED/'

color1 = "#F8EDEB"
color3 = "#F49595"
num_points = 2000
grad = get_color_gradient(color1, color3, num_points)
cmap = LinearSegmentedColormap.from_list(name='test',colors=grad)

# %%
sim = 1

zeta = np.loadtxt(path+'../final_bias_from_hills_1us/COLVAR_REW.{}'.format(sim))[:,1]
SASA = np.loadtxt(path+'../RMSD_SASA_data/sasa_chainA_TYR67_{}.xvg'.format(sim),skiprows=25)[:,2]
time = np.loadtxt(path+'../RMSD_SASA_data/sasa_chainA_TYR67_{}.xvg'.format(sim),skiprows=25)[:,0]/1000
time = time[::25]
zeta = zeta[::25]
SASA = SASA[::25]
print(zeta.shape)

fontsize = 10


plt.figure(figsize = (4.5,2.))
sc = plt.scatter(time,zeta,c = SASA,cmap=cmap,s=3, rasterized=True)
plt.colorbar(sc,label = 'SASA (nm$^{2}$)',ticks=[0,1,2])
plt.clim(0,2)
plt.xlabel('Time (ns)',fontsize = fontsize)
plt.ylabel('\u03B6',fontsize = fontsize)
plt.ylim(-np.pi,np.pi)
plt.yticks(ticks=[-np.pi,0,np.pi],labels=['-\u03C0',0,'\u03C0'])
plt.xlim(0,1000)

plt.tight_layout()
plt.savefig('ZETA_COL_SASA_SIM{}.pdf'.format(sim), dpi=300)
# Out:
# (2001,)

# %%
sim = 2

zeta = np.loadtxt(path+'../final_bias_from_hills_1us/COLVAR_REW.{}'.format(sim))[:,1]
SASA = np.loadtxt(path+'../RMSD_SASA_data/sasa_chainA_TYR67_{}.xvg'.format(sim),skiprows=25)[:,2]
time = np.loadtxt(path+'../RMSD_SASA_data/sasa_chainA_TYR67_{}.xvg'.format(sim),skiprows=25)[:,0]/1000
time = time[::25]
zeta = zeta[::25]
SASA = SASA[::25]
print(zeta.shape)

fontsize = 10


plt.figure(figsize = (4.5,2.))
sc = plt.scatter(time,zeta,c = SASA,cmap=cmap,s=3, rasterized=True)
plt.colorbar(sc,label = 'SASA (nm$^{2}$)',ticks=[0,1,2])
plt.clim(0,2)
plt.xlabel('Time (ns)',fontsize = fontsize)
plt.ylabel('\u03B6',fontsize = fontsize)
plt.ylim(-np.pi,np.pi)
plt.yticks(ticks=[-np.pi,0,np.pi],labels=['-\u03C0',0,'\u03C0'])
plt.xlim(0,1000)

plt.tight_layout()
plt.savefig('ZETA_COL_SASA_SIM{}.pdf'.format(sim), dpi=300)
# Out:
# (2001,)

# %%
sim = 3

zeta = np.loadtxt(path+'../final_bias_from_hills_1us/COLVAR_REW.{}'.format(sim))[:,1]
SASA = np.loadtxt(path+'../RMSD_SASA_data/sasa_chainA_TYR67_{}.xvg'.format(sim),skiprows=25)[:,2]
time = np.loadtxt(path+'../RMSD_SASA_data/sasa_chainA_TYR67_{}.xvg'.format(sim),skiprows=25)[:,0]/1000
time = time[::25]
zeta = zeta[::25]
SASA = SASA[::25]
print(zeta.shape)

fontsize = 10


plt.figure(figsize = (4.5,2.))
sc = plt.scatter(time,zeta,c = SASA,cmap=cmap,s=3, rasterized=True)
plt.colorbar(sc,label = 'SASA (nm$^{2}$)',ticks=[0,1,2])
plt.clim(0,2)
plt.xlabel('Time (ns)',fontsize = fontsize)
plt.ylabel('\u03B6',fontsize = fontsize)
plt.ylim(-np.pi,np.pi)
plt.yticks(ticks=[-np.pi,0,np.pi],labels=['-\u03C0',0,'\u03C0'])
plt.xlim(0,1000)

plt.tight_layout()
plt.savefig('ZETA_COL_SASA_SIM{}.pdf'.format(sim), dpi=300)
# Out:
# (2001,)

# %%
# STATIC BIAS CONTINUATION

sim = 1

zeta = read_colvar(path+'../static_bias_CVdata/COLVAR_STATIC.{}'.format(sim))[:,1][::4] # 20 ps sampling
SASA = read_xvg(path+'../static_bias_CVdata/sasa_chainA_TYR67_{}.xvg'.format(sim))[:,2]
time = read_xvg(path+'../static_bias_CVdata/sasa_chainA_TYR67_{}.xvg'.format(sim))[:,0]/1000

time = time-np.min(time) # set to 0 again

time = time[::25]
zeta = zeta[::25]
SASA = SASA[::25]
print(zeta.shape)

fontsize = 10


plt.figure(figsize = (4.5,2.))
sc = plt.scatter(time,zeta,c = SASA,cmap=cmap,s=3, rasterized=True)
plt.colorbar(sc,label = 'SASA (nm$^{2}$)',ticks=[0,1,2])
plt.clim(0,2)
plt.xlabel('Time (ns)',fontsize = fontsize)
plt.ylabel('\u03B6',fontsize = fontsize)
plt.ylim(-np.pi,np.pi)
plt.yticks(ticks=[-np.pi,0,np.pi],labels=['-\u03C0',0,'\u03C0'])
plt.xlim(0,1000)

plt.tight_layout()
plt.savefig('STATIC_ZETA_COL_SASA_SIM{}.pdf'.format(sim), dpi=300)
# Out:
# (1447,)

# %%
# STATIC BIAS CONTINUATION

sim = 2

zeta = read_colvar(path+'../static_bias_CVdata/COLVAR_STATIC.{}'.format(sim))[:,1][::4] # 20 ps sampling
SASA = read_xvg(path+'../static_bias_CVdata/sasa_chainA_TYR67_{}.xvg'.format(sim))[:,2]
time = read_xvg(path+'../static_bias_CVdata/sasa_chainA_TYR67_{}.xvg'.format(sim))[:,0]/1000

time = time-np.min(time) # set to 0 again

time = time[::25]
zeta = zeta[::25]
SASA = SASA[::25]
print(zeta.shape)

fontsize = 10


plt.figure(figsize = (4.5,2.))
sc = plt.scatter(time,zeta,c = SASA,cmap=cmap,s=3, rasterized=True)
plt.colorbar(sc,label = 'SASA (nm$^{2}$)',ticks=[0,1,2])
plt.clim(0,2)
plt.xlabel('Time (ns)',fontsize = fontsize)
plt.ylabel('\u03B6',fontsize = fontsize)
plt.ylim(-np.pi,np.pi)
plt.yticks(ticks=[-np.pi,0,np.pi],labels=['-\u03C0',0,'\u03C0'])
plt.xlim(0,1000)

plt.tight_layout()
plt.savefig('STATIC_ZETA_COL_SASA_SIM{}.pdf'.format(sim), dpi=300)
# Out:
# (681,)

# %%
# STATIC BIAS CONTINUATION

sim = 3

zeta = read_colvar(path+'../static_bias_CVdata/COLVAR_STATIC.{}'.format(sim))[:,1][::4] # 20 ps sampling
SASA = read_xvg(path+'../static_bias_CVdata/sasa_chainA_TYR67_{}.xvg'.format(sim))[:,2]
time = read_xvg(path+'../static_bias_CVdata/sasa_chainA_TYR67_{}.xvg'.format(sim))[:,0]/1000

time = time-np.min(time) # set to 0 again

time = time[::25]
zeta = zeta[::25]
SASA = SASA[::25]
print(zeta.shape)

fontsize = 10


plt.figure(figsize = (4.5,2.))
sc = plt.scatter(time,zeta,c = SASA,cmap=cmap,s=3, rasterized=True)
plt.colorbar(sc,label = 'SASA (nm$^{2}$)',ticks=[0,1,2])
plt.clim(0,2)
plt.xlabel('Time (ns)',fontsize = fontsize)
plt.ylabel('\u03B6',fontsize = fontsize)
plt.ylim(-np.pi,np.pi)
plt.yticks(ticks=[-np.pi,0,np.pi],labels=['-\u03C0',0,'\u03C0'])
plt.xlim(0,1000)

plt.tight_layout()
plt.savefig('STATIC_ZETA_COL_SASA_SIM{}.pdf'.format(sim), dpi=300)
# Out:
# (1215,)
