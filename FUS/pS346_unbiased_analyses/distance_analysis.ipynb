# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import MDAnalysis.analysis.distances
import MDAnalysis as md
import mdtraj as mdj
import MDAnalysis.analysis.contacts
import pandas as pd
import MDAnalysis.analysis.rms
import os
from MDAnalysis.analysis.dihedrals import Dihedral
from MDAnalysis.analysis.rms import RMSF
from MDAnalysis.analysis import rms, align
import matplotlib
matplotlib.rcParams['pdf.fonttype'] = 42

path = '/Volumes/Elements/PTM_project/FUS/pS346/'

# %%
# Calculate distances

# lysine residues to analyse
resids = [312,315,316]

nsims=3

for i in range(1,nsims+1):
    
    print('Sim {}'.format(i))
    
    # load traj
    u = md.Universe(path+"sim{}/processed.pdb".format(i),path+"sim{}/fit.xtc".format(i))
    
    # atom selections
    sp2 = u.select_atoms('resname SP2 and name P')
    
    for lys in resids:
        
        l = u.select_atoms('resid {} and name NZ'.format(lys))
        
        # calculate distances
        dist = []
        
        for frame in range(len(u.trajectory)):
            
            u.trajectory[frame]
            
            d = MDAnalysis.analysis.distances.dist(sp2,l)[2][0]
            
            dist.append(d)
            
        dist = np.array(dist)
        
        np.savetxt(path+"sim{}/Lys{}NZ_pS346P_distance.txt".format(i,lys),dist)
        
    
print('done')
# Out:
# Sim 1
# Sim 2
# Sim 3
# done

# %%
ymax = 35
ymax_rmsd = 8

resids = [312,315,316]
sim=1

plt.figure(figsize = (4,8))

colors = ['darkblue','magenta','lightblue']

vals = []

dat = np.loadtxt(path+"sim{}/rmsd_BB.xvg".format(sim),skiprows=18)
    
rmsd = dat[:,1]*10 # convert to Angstrom
time = dat[:,0]/1000 # convert to nanoseconds

p=1

# three more panels
plt.subplot(4,1,p)
plt.title('RMSD')
plt.plot(time,rmsd,linewidth = 0.6,color = 'black')
plt.xlabel('Time (ns)')
plt.ylabel('BB-RMSD ($\\AA$)')
plt.ylim(0,ymax_rmsd)
plt.xlim(0,np.max(time))

for lys,c in zip(resids,colors):
    p+=1
    dist = np.loadtxt(path+"sim{}/Lys{}NZ_pS346P_distance.txt".format(sim,lys))
    
    dat = np.loadtxt(path+"sim{}/rmsd_BB.xvg".format(sim),skiprows=18)
    
    rmsd = dat[:,1]*10 # convert to Angstrom
    time = dat[:,0]/1000 # convert to nanoseconds

    # three more panels
    plt.subplot(4,1,p)
    plt.plot(time,dist,color = c,linewidth = 0.6)
    plt.title('Lys{} NZ - pS346 P'.format(lys))
    plt.ylim(0,ymax)
    plt.xlim(0,np.max(time))

    
    plt.xlabel('Time (ns)')
    plt.ylabel('Distance ($\\AA$)')


plt.tight_layout()
plt.savefig('Lys_NZ_SP2_P_distances_sim{}.png'.format(sim))

# %%
ymax = 35
ymax_rmsd = 8

resids = [312,315,316]
sim=2

plt.figure(figsize = (4,8))

colors = ['darkblue','magenta','lightblue']

vals = []

dat = np.loadtxt(path+"sim{}/rmsd_BB.xvg".format(sim),skiprows=18)
    
rmsd = dat[:,1]*10 # convert to Angstrom
time = dat[:,0]/1000 # convert to nanoseconds

p=1

# three more panels
plt.subplot(4,1,p)
plt.title('RMSD')
plt.plot(time,rmsd,linewidth = 0.6,color = 'black')
plt.xlabel('Time (ns)')
plt.ylabel('BB-RMSD ($\\AA$)')
plt.ylim(0,ymax_rmsd)
plt.xlim(0,np.max(time))

for lys,c in zip(resids,colors):
    p+=1
    dist = np.loadtxt(path+"sim{}/Lys{}NZ_pS346P_distance.txt".format(sim,lys))
    
    dat = np.loadtxt(path+"sim{}/rmsd_BB.xvg".format(sim),skiprows=18)
    
    rmsd = dat[:,1]*10 # convert to Angstrom
    time = dat[:,0]/1000 # convert to nanoseconds

    # three more panels
    plt.subplot(4,1,p)
    plt.plot(time,dist,color = c,linewidth = 0.6)
    plt.title('Lys{} NZ - pS346 P'.format(lys))
    plt.ylim(0,ymax)
    plt.xlim(0,np.max(time))

    
    plt.xlabel('Time (ns)')
    plt.ylabel('Distance ($\\AA$)')


plt.tight_layout()
plt.savefig('Lys_NZ_SP2_P_distances_sim{}.png'.format(sim))

# %%
ymax = 35
ymax_rmsd = 8

resids = [312,315,316]
sim=3

plt.figure(figsize = (4,8))

colors = ['darkblue','magenta','lightblue']

vals = []

dat = np.loadtxt(path+"sim{}/rmsd_BB.xvg".format(sim),skiprows=18)
    
rmsd = dat[:,1]*10 # convert to Angstrom
time = dat[:,0]/1000 # convert to nanoseconds

p=1

# three more panels
plt.subplot(4,1,p)
plt.title('RMSD')
plt.plot(time,rmsd,linewidth = 0.6,color = 'black')
plt.xlabel('Time (ns)')
plt.ylabel('BB-RMSD ($\\AA$)')
plt.ylim(0,ymax_rmsd)
plt.xlim(0,np.max(time))

for lys,c in zip(resids,colors):
    p+=1
    dist = np.loadtxt(path+"sim{}/Lys{}NZ_pS346P_distance.txt".format(sim,lys))
    
    dat = np.loadtxt(path+"sim{}/rmsd_BB.xvg".format(sim),skiprows=18)
    
    rmsd = dat[:,1]*10 # convert to Angstrom
    time = dat[:,0]/1000 # convert to nanoseconds

    # three more panels
    plt.subplot(4,1,p)
    plt.plot(time,dist,color = c,linewidth = 0.6)
    plt.title('Lys{} NZ - pS346 P'.format(lys))
    plt.ylim(0,ymax)
    plt.xlim(0,np.max(time))

    
    plt.xlabel('Time (ns)')
    plt.ylabel('Distance ($\\AA$)')


plt.tight_layout()
plt.savefig('Lys_NZ_SP2_P_distances_sim{}.png'.format(sim))

# %%
# individual simulation plots of the buried PTMs

resnames = ['Lys','Lys','Lys','Lys']
resids = [312,315,316,316]
atoms = ['NZ','NZ','NZ','NZ']

fullnames = []
for resn,resi in zip(resnames,resids):
    fullnames.append(resn+str(resi))

colors = ['#F49595','#F1CEBE','#F8EDEB']

nsims=3
Nmov = 50

plt.figure(figsize= (4,5))

df = pd.DataFrame()

averages = []
errors = []
IDX=1
for rn,resi,at in zip(resnames,resids,atoms):
    
    plt.subplot(4,1,IDX)
    
    vals = []
    
    for s in range(1,nsims+1):
        dist = np.loadtxt(path+"sim{}/{}{}{}_pS346P_distance.txt".format(s,rn,resi,at))
        DAT_FOR_AVG = dist[50000:] # discard first 1us for average
        DAT_FOR_AVG = (DAT_FOR_AVG<5.0)*1
        vals.append(np.mean(DAT_FOR_AVG))
        dist = dist[::1000]
        dat = np.loadtxt(path+"sim{}/rmsd_BB.xvg".format(s),skiprows=18)[::1000]
        time = dat[:,0]/1000 # convert to nanoseconds
        
        plt.plot(time,dist,color = colors[s-1],linewidth = 1.0)
    

    mu = np.mean(vals)
    err = np.std(vals)/np.sqrt(3)
    averages.append(mu)
    errors.append(err)
    
    print(mu)
    print(err)
    plt.ylim(0,30)
    plt.xlim(0,5000)

    if IDX==4:
        plt.xlabel('Time (ns)')
        plt.ylabel('Distance (A)')
    else:
        plt.ylabel('Distance (A)')

    IDX+=1

        
df['Residue'] = fullnames
df['Probability'] = np.round(averages,2)
df['Error'] = np.round(errors,2)
df.to_csv('Phosphate_contact_prob.csv')


plt.tight_layout()
plt.savefig('final_distances.pdf')
# Out:
# 0.949413586265402
# 0.007419754876945899
# 0.35275990286715236
# 0.14061974597001797
# 0.18986238402141323
# 0.04046907354067628
# 0.18986238402141323
# 0.04046907354067628

# %%
# plot
df = pd.read_csv('Phosphate_contact_prob.csv')
df.plot(x='Residue',y='Probability',yerr= np.array(df['Error']),
       kind='bar',figsize = (4,1.5),legend=False,color = '#FEC89A',edgecolor = 'black',
       capsize = 2)

plt.xticks(rotation=0)
plt.ylim(0,1)

plt.ylabel('Probability')

plt.tight_layout()
plt.savefig('phosphate_contact_prob_barplot.pdf')
